# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing The Dataset

# %%
dataset=pd.read_csv("/content/HousingData.csv")

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
target = dataset['MEDV']

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
## Summarizing The Stats of the data
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
## Check the missing Values
dataset.isnull().sum()
dataset.dropna()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 5       18.7  394.12   5.21  28.7
# ..       ...     ...    ...   ...
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
#
# [394 rows x 14 columns]

# %%
### EXploratory Data Analysis
## Correlation
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# B       -0.381411  0.171303 -0.360532  0.051264 -0.380051  0.128069 -0.275303
# LSTAT    0.444943 -0.414193  0.590690 -0.047424  0.582641 -0.614339  0.602891
# MEDV    -0.391363  0.373136 -0.481772  0.181391 -0.427321  0.695360 -0.394656
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.374166  0.624765  0.580595  0.281110 -0.381411  0.444943 -0.391363
# ZN       0.656739 -0.310919 -0.312371 -0.414046  0.171303 -0.414193  0.373136
# INDUS   -0.711709  0.604533  0.731055  0.390954 -0.360532  0.590690 -0.481772
# CHAS    -0.093971  0.001468 -0.032304 -0.111304  0.051264 -0.047424  0.181391
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.582641 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.614339  0.695360
# AGE     -0.744844  0.458349  0.509114  0.269226 -0.275303  0.602891 -0.394656
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.493328  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.479541 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.536110 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.375966 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.369889  0.333461
# LSTAT   -0.493328  0.479541  0.536110  0.375966 -0.369889  1.000000 -0.735822
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.735822  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)

# %% [markdown]
# ## Analyzing The Correlated Features

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.191178  0.401863 -0.054355  0.417130 -0.219150  0.354342
# ZN      -0.191178  1.000000 -0.531871 -0.037229 -0.513704  0.320800 -0.563801
# INDUS    0.401863 -0.531871  1.000000  0.059859  0.764866 -0.390234  0.638431
# CHAS    -0.054355 -0.037229  0.059859  1.000000  0.075097  0.104885  0.078831
# NOX      0.417130 -0.513704  0.764866  0.075097  1.000000 -0.302188  0.731548
# RM      -0.219150  0.320800 -0.390234  0.104885 -0.302188  1.000000 -0.247337
# AGE      0.354342 -0.563801  0.638431  0.078831  0.731548 -0.247337  1.000000
# DIS     -0.374166  0.656739 -0.711709 -0.093971 -0.769230  0.205246 -0.744844
# RAD      0.624765 -0.310919  0.604533  0.001468  0.611441 -0.209847  0.458349
# TAX      0.580595 -0.312371  0.731055 -0.032304  0.668023 -0.292048  0.509114
# PTRATIO  0.281110 -0.414046  0.390954 -0.111304  0.188933 -0.355501  0.269226
# B       -0.381411  0.171303 -0.360532  0.051264 -0.380051  0.128069 -0.275303
# LSTAT    0.444943 -0.414193  0.590690 -0.047424  0.582641 -0.614339  0.602891
# MEDV    -0.391363  0.373136 -0.481772  0.181391 -0.427321  0.695360 -0.394656
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.374166  0.624765  0.580595  0.281110 -0.381411  0.444943 -0.391363
# ZN       0.656739 -0.310919 -0.312371 -0.414046  0.171303 -0.414193  0.373136
# INDUS   -0.711709  0.604533  0.731055  0.390954 -0.360532  0.590690 -0.481772
# CHAS    -0.093971  0.001468 -0.032304 -0.111304  0.051264 -0.047424  0.181391
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.582641 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.614339  0.695360
# AGE     -0.744844  0.458349  0.509114  0.269226 -0.275303  0.602891 -0.394656
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.493328  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.479541 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.536110 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.375966 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.369889  0.333461
# LSTAT   -0.493328  0.479541  0.536110  0.375966 -0.369889  1.000000 -0.735822
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.735822  1.000000

# %%
plt.scatter(dataset['CRIM'],dataset['MEDV'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['RM'],dataset['MEDV'])
plt.xlabel("RM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x="RM",y="MEDV",data=dataset)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
sns.regplot(x="LSTAT",y="MEDV",data=dataset)
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %%
sns.regplot(x="CHAS",y="MEDV",data=dataset)
# Out:
# <Axes: xlabel='CHAS', ylabel='MEDV'>

# %%
sns.regplot(x="PTRATIO",y="MEDV",data=dataset)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='MEDV'>

# %%
## Independent and Dependent features

X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
X.fillna(5, inplace=True)

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.00

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   5.0  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.00
# ..       ...     ...    ...
# 501     21.0  391.99   5.00
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
np.where(np.isnan(X))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
np.nan_to_num(X)
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30   5.00
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13
# ..       ...     ...    ...
# 106     20.9  395.67  18.66
# 270     18.6  388.65  13.00
# 348     17.0  390.94   5.99
# 435     20.2  109.85  23.27
# 102     20.9   70.80  10.63
#
# [354 rows x 13 columns]

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 173  0.09178   0.0   5.00   0.0  0.510  6.416    5.0  2.6463    5  296
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980   24  666
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# 491     20.1  390.11  18.07
# 72      19.2  390.91   5.52
# 452     20.2  385.09  17.27
# ..       ...     ...    ...
# 441     20.2  385.96   5.00
# 23      21.0  394.54  19.88
# 225     17.4  382.00   4.63
# 433     20.2  100.19  16.22
# 447     20.2  388.52  16.44
#
# [152 rows x 13 columns]

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.42778745, -0.49900529, -1.25103871, ...,  0.18727079,
#          0.39651419, -0.9807664 ],
#        [-0.41545694, -0.49900529, -0.10866448, ..., -0.21208981,
#          0.3870674 , -1.01035572],
#        [-0.410628  , -0.49900529, -0.56094547, ..., -0.16771641,
#          0.42854113, -0.2762586 ],
#        ...,
#        [-0.42958619,  3.07324693, -1.27584122, ..., -0.56707702,
#          0.35987906, -0.87086318],
#        [ 0.92132711, -0.49900529,  1.07164299, ...,  0.8528718 ,
#         -2.87841346,  1.56391576],
#        [-0.40367792, -0.49900529, -0.32021527, ...,  1.16348561,
#         -3.32828832, -0.21707995]])

# %%
X_test
# Out:
# array([[-0.42028103, -0.49900529, -0.83960891, ..., -0.74457062,
#          0.41241246, -0.44111343],
#        [-0.42456453,  1.28712082, -0.63389401, ..., -0.30083661,
#          0.42854113, -1.21748102],
#        [-0.41858896, -0.49900529,  2.47809095, ...,  0.8084984 ,
#          0.35031705,  0.83122765],
#        ...,
#        [-0.36753725, -0.49900529, -0.6645324 , ..., -0.38958342,
#          0.25688594, -1.0624893 ],
#        [ 0.24506625, -0.49900529,  1.07164299, ...,  0.8528718 ,
#         -2.98970133,  0.57055977],
#        [ 0.77156825, -0.49900529,  1.07164299, ...,  0.8528718 ,
#          0.33199949,  0.60155811]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regression.coef_)
# Out:
# [-1.18691007  0.80679722  0.18330582 -0.16284313 -1.67133327  3.25503989
#  -0.74250835 -3.1323191   2.16641925 -1.56945925 -2.17530636  1.08506557
#  -3.35909486]

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
## on which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### Prediction With Test Data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([30.77533679, 33.54698278, 14.89269646, 25.52569156, 18.95548728,
#        22.93015868, 19.5951354 , 14.48610412, 22.55207978, 20.73500481,
#        21.77129077, 17.87236992, -6.8637954 , 21.81368872, 18.89204543,
#        29.57875561, 20.1366443 ,  5.08902594, 41.42642625, 17.56172133,
#        28.67012911, 30.64251172, 11.07029531, 26.32721538, 17.85601899,
#        15.43449695, 24.96836288, 14.61388466, 19.23238136, 19.42921148,
#        22.22726263, 25.20587339, 25.61188344, 17.68064572, 16.65625898,
#        17.60047457, 31.00834307, 20.24403415, 20.91421951, 26.44132545,
#        14.34385352, 32.15729689, 43.61514601, 17.65119281, 27.24534053,
#        16.93852817, 13.64194465, 26.49411106, 20.20586989, 30.22322694,
#        21.22948979, 35.550086  , 15.73400149, 26.06316737, 40.20951729,
#        22.91274779, 18.14372498, 33.3175003 , 25.15593341, 11.98978819,
#        22.87688332, 31.29664904, 31.50117378, 16.32230444, 20.72365623,
#        13.31746386, 20.4373274 , 26.30615511, 31.4372628 , 11.83998351,
#        20.94696035, 27.1289559 , 11.13425269, 13.94842921, 23.94117779,
#         5.56427215, 21.20486108, 42.34753425, 18.54258883,  9.11332442,
#        21.10227272, 13.19492152, 21.72341342,  9.41173608, 22.85806129,
#        28.91807789, 19.28561741, 25.68362183, 29.48374019, 19.8786188 ,
#        26.01751744,  5.4174891 , 19.71183433, 15.01853945, 12.19696381,
#        20.31909847, 24.15631781, -0.4733956 , 13.63170676, 15.7485018 ,
#        22.508662  , 24.59677674, 10.63931159, 19.37940032, 22.71257775,
#        14.28380154, 18.19961831, 25.84572815, 21.03704919, 24.56703252,
#         7.88083121, 20.51132854, 21.97828496, 27.55562101, 32.35481977,
#        14.85544639, 35.03680519, 12.65350009, 21.21079765, 28.13624885,
#        15.18201921, 25.09118758,  2.48892464, 23.67252945, 26.22634143,
#        22.9918852 , 25.38264033, 33.38227456, 19.62467939, 39.05242045,
#        16.71667477, 25.72044864, 17.33355619, 20.77128883, 10.32835459,
#        20.7569587 , 22.55165568, 32.45001327, 31.91034786, 15.24436318,
#        16.7374526 , 29.19367791, 25.1598843 , 13.75367071,  6.33173239,
#        26.44117876, 20.38785904, 24.52506592, 13.31538503, 40.75632225,
#        16.62619895, 18.23019383])

# %% [markdown]
# ## Assumptions

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
## Residuals
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 173   -7.175337
# 274   -1.146983
# 491   -1.292696
# 72    -2.725692
# 452   -2.855487
#          ...
# 441   -7.425066
# 23     1.184615
# 225    9.243678
# 433   -2.326199
# 447   -5.630194
# Name: MEDV, Length: 152, dtype: float64

# %%
## Plot this residuals

sns.displot(residuals,kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.2370566751016114
# 22.393122942678193
# 4.732137248926556

# %% [markdown]
# ## R square and adjusted R square

# %% [markdown]
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.6994739948458807

# %% [markdown]
# **Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]**
#
# where:
#
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6711635740704927

# %% [markdown]
# ## Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.00

# %%
t = scaler.transform([[0.00632,18.0,2.31,0.0,0.538,6.575,65.2, 4.0900,1,296,15.3,396.90,4.98]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
regression.predict(t)
# Out:
# array([30.22322694])
